# %% [markdown]
# <a href="https://colab.research.google.com/github/mobinsamin/3D-MedDiffusion/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-telegram-bot

# %%
from telegram import Update
from telegram.ext import ApplicationBuilder, ContextTypes, CommandHandler

# این تابع وقتی کسی دکمه استارت را بزند اجرا می‌شود
async def start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    await context.bot.send_message(
        chat_id=update.effective_chat.id,
        text="سلام! من ویدارا هستم. فعلا زنده‌ام اما هنوز کار گرافیکی بلد نیستم!"
    )

# اینجا مغز اصلی بات است
if __name__ == '__main__':
    # توکن خود را دقیقاً داخل دو علامت نقل قول پایین بگذارید
    TOKEN = "8573947668:AAFFSLwkdFq-YKytn5rp6heNFwX_AEGwiy8"

    application = ApplicationBuilder().token(TOKEN).build()

    # دستور استارت را به بات یاد می‌دهیم
    start_handler = CommandHandler('start', start)
    application.add_handler(start_handler)

    print("بات روشن شد! برو تو تلگرام تستش کن...")
    # روشن کردن بات
    application.run_polling()
# Out:
# بات روشن شد! برو تو تلگرام تستش کن...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/telegram/ext/_application.py in __run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1053         try:
# -> 1054             loop.run_until_complete(self._bootstrap_initialize(max_retries=bootstrap_retries))
#    1055             if self.post_init:
#
# /usr/lib/python3.12/asyncio/base_events.py in run_until_complete(self, future)
#     666         self._check_closed()
# --> 667         self._check_running()
#     668
#
# /usr/lib/python3.12/asyncio/base_events.py in _check_running(self)
#     625         if self.is_running():
# --> 626             raise RuntimeError('This event loop is already running')
#     627         if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# ...

# %% [markdown]
# ### Loading data from a CSV file

# %%
import pandas as pd

# Example: Loading a CSV file
# Assuming you have a CSV file named 'my_data.csv' in your current directory or a specified path
# To use a file from Google Drive, replace 'my_data.csv' with the full path, e.g., '/content/drive/MyDrive/my_data.csv'
# df_csv = pd.read_csv('my_data.csv')
# print('DataFrame from CSV:')
# display(df_csv.head())

print('Example for pd.read_csv():')
print('df_csv = pd.read_csv("path/to/your/file.csv")')
# Out:
# Example for pd.read_csv():
# df_csv = pd.read_csv("path/to/your/file.csv")
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py:6049: RuntimeWarning: coroutine 'Application.shutdown' was never awaited
#   index = properties.AxisProperty(
# ...
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py:6049: RuntimeWarning: coroutine 'Application._bootstrap_initialize' was never awaited
#   index = properties.AxisProperty(
# ...

# %% [markdown]
# ### Loading data from an Excel file

# %%
import pandas as pd

# Example: Loading an Excel file
# df_excel = pd.read_excel('my_spreadsheet.xlsx', sheet_name='Sheet1')
# print('\nDataFrame from Excel:')
# display(df_excel.head())

print('Example for pd.read_excel():')
print('df_excel = pd.read_excel("path/to/your/spreadsheet.xlsx", sheet_name="Sheet1")')
# Out:
# Example for pd.read_excel():
# df_excel = pd.read_excel("path/to/your/spreadsheet.xlsx", sheet_name="Sheet1")

# %% [markdown]
# ### Loading data from a SQL database

# %%
import pandas as pd
# import sqlalchemy # You might need to install this: !pip install sqlalchemy

# Example: Loading data from a SQL query (requires a database connection)
# from sqlalchemy import create_engine
# engine = create_engine('sqlite:///my_database.db') # Example for SQLite
# df_sql = pd.read_sql_query('SELECT * FROM my_table', engine)
# print('\nDataFrame from SQL:')
# display(df_sql.head())

print('Example for pd.read_sql_query():')
print('import sqlalchemy\nengine = sqlalchemy.create_engine("sqlite:///my_database.db")\ndf_sql = pd.read_sql_query("SELECT * FROM my_table", engine)')
# Out:
# Example for pd.read_sql_query():
# import sqlalchemy
# engine = sqlalchemy.create_engine("sqlite:///my_database.db")
# df_sql = pd.read_sql_query("SELECT * FROM my_table", engine)

# %% [markdown]
# ### Loading data from JSON

# %%
import pandas as pd

# Example: Loading a JSON file
# df_json = pd.read_json('my_data.json')
# print('\nDataFrame from JSON:')
# display(df_json.head())

print('Example for pd.read_json():')
print('df_json = pd.read_json("path/to/your/file.json")')
# Out:
# Example for pd.read_json():
# df_json = pd.read_json("path/to/your/file.json")

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# After running the above cell, you will be prompted to authorize Google Drive access. Once authorized, your Google Drive will be mounted at `/content/drive`, and you can access your files from there.
